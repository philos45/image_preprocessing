# %%
import pandas as pd
import numpy as np
import json

# %%
class_name = pd.read_csv('Fdong.csv')

# %%
import os

def search(dirname):
    json_list = []
    filenames = os.listdir(dirname)
    for filename in filenames:
        full_filename = os.path.join(dirname, filename)
        ext = os.path.splitext(full_filename)[-1]
        if ext == '.json': 
            json_list.append(full_filename.split('/')[-1])
            
    return json_list
json_ls = search('/home/munkyu/trans_code/평동데이터/')
json_ls=sorted(json_ls)

# %% [markdown]
# <hr>

# %%
for file_length in range(len(json_ls)):
    with open('./평동데이터/{}'.format(json_ls[file_length]), 'r') as f:
        json_data = json.load(f)
        
    for idx in range(len(json_data['shapes'])):
        if json_data['shapes'][idx]['label'] == class_name['korean'][0]:
            json_data['shapes'][idx]['label'] = class_name['eng'][0]

        if json_data['shapes'][idx]['label'] == class_name['korean'][1]:
            json_data['shapes'][idx]['label'] = class_name['eng'][1]

        if json_data['shapes'][idx]['label'] == class_name['korean'][2]:
            json_data['shapes'][idx]['label'] = class_name['eng'][2]

        if json_data['shapes'][idx]['label'] == class_name['korean'][3]:
            json_data['shapes'][idx]['label'] = class_name['eng'][3]

        if json_data['shapes'][idx]['label'] == class_name['korean'][4]:
            json_data['shapes'][idx]['label'] = class_name['eng'][4]

        if json_data['shapes'][idx]['label'] == class_name['korean'][5]:
            json_data['shapes'][idx]['label'] = class_name['eng'][5]

        if json_data['shapes'][idx]['label'] == class_name['korean'][6]:
            json_data['shapes'][idx]['label'] = class_name['eng'][6]

        if json_data['shapes'][idx]['label'] == class_name['korean'][7]:
            json_data['shapes'][idx]['label'] = class_name['eng'][7]

        if json_data['shapes'][idx]['label'] == class_name['korean'][8]:
            json_data['shapes'][idx]['label'] = class_name['eng'][8]

        if json_data['shapes'][idx]['label'] == class_name['korean'][9]:
            json_data['shapes'][idx]['label'] = class_name['eng'][9]

        if json_data['shapes'][idx]['label'] == class_name['korean'][10]:
            json_data['shapes'][idx]['label'] = class_name['eng'][10]

        if json_data['shapes'][idx]['label'] == class_name['korean'][11]:
            json_data['shapes'][idx]['label'] = class_name['eng'][11]

        if json_data['shapes'][idx]['label'] == class_name['korean'][12]:
            json_data['shapes'][idx]['label'] = class_name['eng'][12]

        if json_data['shapes'][idx]['label'] == class_name['korean'][13]:
            json_data['shapes'][idx]['label'] = class_name['eng'][13]

        if json_data['shapes'][idx]['label'] == class_name['korean'][14]:
            json_data['shapes'][idx]['label'] = class_name['eng'][14]

        if json_data['shapes'][idx]['label'] == class_name['korean'][15]:
            json_data['shapes'][idx]['label'] = class_name['eng'][15]

        if json_data['shapes'][idx]['label'] == class_name['korean'][16]:
            json_data['shapes'][idx]['label'] = class_name['eng'][16]

        if json_data['shapes'][idx]['label'] == class_name['korean'][17]:
            json_data['shapes'][idx]['label'] = class_name['eng'][17]

        if json_data['shapes'][idx]['label'] == class_name['korean'][18]:
            json_data['shapes'][idx]['label'] = class_name['eng'][18]

        if json_data['shapes'][idx]['label'] == class_name['korean'][19]:
            json_data['shapes'][idx]['label'] = class_name['eng'][19]

        if json_data['shapes'][idx]['label'] == class_name['korean'][20]:
            json_data['shapes'][idx]['label'] = class_name['eng'][20]

        if json_data['shapes'][idx]['label'] == class_name['korean'][21]:
            json_data['shapes'][idx]['label'] = class_name['eng'][21]

        if json_data['shapes'][idx]['label'] == class_name['korean'][22]:
            json_data['shapes'][idx]['label'] = class_name['eng'][22]

        if json_data['shapes'][idx]['label'] == class_name['korean'][23]:
            json_data['shapes'][idx]['label'] = class_name['eng'][23]

        if json_data['shapes'][idx]['label'] == class_name['korean'][24]:
            json_data['shapes'][idx]['label'] = class_name['eng'][24]

        if json_data['shapes'][idx]['label'] == class_name['korean'][25]:
            json_data['shapes'][idx]['label'] = class_name['eng'][25]

        if json_data['shapes'][idx]['label'] == class_name['korean'][26]:
            json_data['shapes'][idx]['label'] = class_name['eng'][26]

        if json_data['shapes'][idx]['label'] == class_name['korean'][27]:
            json_data['shapes'][idx]['label'] = class_name['eng'][27]

        if json_data['shapes'][idx]['label'] == class_name['korean'][28]:
            json_data['shapes'][idx]['label'] = class_name['eng'][28]

        if json_data['shapes'][idx]['label'] == class_name['korean'][29]:
            json_data['shapes'][idx]['label'] = class_name['eng'][29]

        if json_data['shapes'][idx]['label'] == class_name['korean'][30]:
            json_data['shapes'][idx]['label'] = class_name['eng'][30]

        if json_data['shapes'][idx]['label'] == class_name['korean'][31]:
            json_data['shapes'][idx]['label'] = class_name['eng'][31]

        if json_data['shapes'][idx]['label'] == class_name['korean'][32]:
            json_data['shapes'][idx]['label'] = class_name['eng'][32]

        if json_data['shapes'][idx]['label'] == class_name['korean'][33]:
            json_data['shapes'][idx]['label'] = class_name['eng'][33]

        if json_data['shapes'][idx]['label'] == class_name['korean'][34]:
            json_data['shapes'][idx]['label'] = class_name['eng'][34]

        if json_data['shapes'][idx]['label'] == class_name['korean'][35]:
            json_data['shapes'][idx]['label'] = class_name['eng'][35]

        if json_data['shapes'][idx]['label'] == class_name['korean'][36]:
            json_data['shapes'][idx]['label'] = class_name['eng'][36]

        if json_data['shapes'][idx]['label'] == class_name['korean'][37]:
            json_data['shapes'][idx]['label'] = class_name['eng'][37]

        if json_data['shapes'][idx]['label'] == class_name['korean'][38]:
            json_data['shapes'][idx]['label'] = class_name['eng'][38]

#         if json_data['shapes'][idx]['label'] == class_name['korean'][39]:
#             json_data['shapes'][idx]['label'] = class_name['eng'][39]

#         if json_data['shapes'][idx]['label'] == class_name['korean'][40]:
#             json_data['shapes'][idx]['label'] = class_name['eng'][40]

#         if json_data['shapes'][idx]['label'] == class_name['korean'][41]:
#             json_data['shapes'][idx]['label'] = class_name['eng'][41]

#         if json_data['shapes'][idx]['label'] == class_name['korean'][42]:
#             json_data['shapes'][idx]['label'] = class_name['eng'][42]

#         if json_data['shapes'][idx]['label'] == class_name['korean'][43]:
#             json_data['shapes'][idx]['label'] = class_name['eng'][43]

#         if json_data['shapes'][idx]['label'] == class_name['korean'][44]:
#             json_data['shapes'][idx]['label'] = class_name['eng'][44]

#         if json_data['shapes'][idx]['label'] == class_name['korean'][45]:
#             json_data['shapes'][idx]['label'] = class_name['eng'][45]

#         if json_data['shapes'][idx]['label'] == class_name['korean'][46]:
#             json_data['shapes'][idx]['label'] = class_name['eng'][46]

#         if json_data['shapes'][idx]['label'] == class_name['korean'][47]:
#             json_data['shapes'][idx]['label'] = class_name['eng'][47]

#         if json_data['shapes'][idx]['label'] == class_name['korean'][48]:
#             json_data['shapes'][idx]['label'] = class_name['eng'][48]

#         if json_data['shapes'][idx]['label'] == class_name['korean'][49]:
#             json_data['shapes'][idx]['label'] = class_name['eng'][49]

#         if json_data['shapes'][idx]['label'] == class_name['korean'][50]:
#             json_data['shapes'][idx]['label'] = class_name['eng'][50]
            
            
    with open('./평동데이터/{}'.format(json_ls[file_length]), 'w', encoding='utf-8') as make_file:

        json.dump(json_data, make_file, indent="\t")
        
    print(json_ls[file_length], 'is done')
    print(file_length,'/',len(json_ls))
# Out:
# ladybug_panoramic_000601.json is done
# 0 / 404
# ladybug_panoramic_000602.json is done
# 1 / 404
# ladybug_panoramic_000603.json is done
# 2 / 404
# ladybug_panoramic_000604.json is done
# 3 / 404
# ladybug_panoramic_000605.json is done
# 4 / 404
# ladybug_panoramic_000606.json is done
# 5 / 404
# ladybug_panoramic_000607.json is done
# 6 / 404
# ladybug_panoramic_000608.json is done
# 7 / 404
# ladybug_panoramic_000609.json is done
# 8 / 404
# ladybug_panoramic_000610.json is done
# 9 / 404
# ladybug_panoramic_000611.json is done
# 10 / 404
# ladybug_panoramic_000612.json is done
# 11 / 404
# ladybug_panoramic_000613.json is done
# 12 / 404
# ladybug_panoramic_000614.json is done
# 13 / 404
# ladybug_panoramic_000615.json is done
# 14 / 404
# ladybug_panoramic_000616.json is done
# 15 / 404
# ladybug_panoramic_000617.json is done
# 16 / 404
# ladybug_panoramic_000618.json is done
# 17 / 404
# ladybug_panoramic_000619.json is done
# 18 / 404
# ladybug_panoramic_000620.json is done
# ...
